# %% [markdown]
# # V-JEPA 2

# %% [markdown]
# V-JEPA 2 is a new open 1.2B video embedding model by Meta, which attempts to capture the physical world modelling through video ⏯️
#
# The model can be used for various tasks for video: fine-tuning for downstream tasks like video classification, or any task involving embeddings (similarity, retrieval and more!).
#
# You can check all V-JEPA 2 checkpoints and the datasets that come with this release [in this collection](collection_link). You can also read about the release [here](blog_link).
#
# In this notebook we will go through:
# 1. Using V-JEPA 2 as feature extractor,
# 2. Using V-JEPA 2 for video classification
# 3. fine-tuning V-JEPA 2, on [UCF-101 action recognition dataset](https://huggingface.co/datasets/sayakpaul/ucf101-subset) using transformers.
#
# Let's go!

# %% [markdown]
# We need to install accelerate, datasets and transformers' main branch.

# %%
# !pip install -U https://github.com/huggingface/transformers

# %% [markdown]
# torchcodec 0.2.1 supports Colab, which is supported by different torch and torchvision versions, so let's update them too.

# %%
# !pip install -q torch==2.6.0 torchvision==0.21.0
# !pip install -q torchcodec==0.2.1

import torch
print("Torch:", torch.__version__)
from torchcodec.decoders import VideoDecoder # validate it works
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 115.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.4/766.4 kB 21.4 MB/s eta 0:00:00
# Torch: 2.6.0+cu124

# %% [markdown]
# ## Simple Inference
#
# **Inference with Embeddings**
#
# You can initialize the V-JEPA 2 with ViT Giant checkpoint as follows. Feel free to replace the ID with the one you want to use. Here's [the model collection](https://huggingface.co/collections/facebook/v-jepa-2-6841bad8413014e185b497a6).

# %%
from transformers import AutoVideoProcessor, AutoModel

model = AutoModel.from_pretrained("facebook/vjepa2-vitg-fpc64-384").to("cuda")
processor = AutoVideoProcessor.from_pretrained("facebook/vjepa2-vitg-fpc64-384")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# Simply infer to get the embeddings.

# %%
import torch
from torchcodec.decoders import VideoDecoder
import numpy as np

video_url = "https://huggingface.co/datasets/merve/vlm_test_images/resolve/main/holding_phone.mp4"
vr = VideoDecoder(video_url)
frame_idx = np.arange(0, 32) # choosing some frames. here, you can define more complex sampling strategy
video_frames = vr.get_frames_at(indices=frame_idx).data  # T x C x H x W
video = processor(video_frames, return_tensors="pt").to(model.device)
with torch.no_grad():
    video_embeddings = model.get_vision_features(**video)

print(video_embeddings.shape)
del model
# Out:
# torch.Size([1, 9216, 1408])

# %% [markdown]
# **Inference for Video Classification**
#
# Meta also provides a model trained on SomethingSomething-v2, a dataset of human-object interactions with 174 classes.

# %%
from transformers import VJEPA2ForVideoClassification, VJEPA2VideoProcessor

model = VJEPA2ForVideoClassification.from_pretrained("facebook/vjepa2-vitl-fpc16-256-ssv2").to("cuda")
processor = VJEPA2VideoProcessor.from_pretrained("facebook/vjepa2-vitl-fpc16-256-ssv2")

# %% [markdown]
# We can pass the same frames to the new processor.

# %%
inputs = processor(video_frames, return_tensors="pt").to(model.device)

with torch.no_grad():
    outputs = model(**inputs)
    logits = outputs.logits

predicted_label = logits.argmax(-1).item()
print(model.config.id2label[predicted_label])
# Out:
# Touching (without moving) [part] of [something]

# %% [markdown]
# ## Data Preprocessing for Fine-tuning

# %% [markdown]
# Let's load the dataset first. UCF-101 consists of 101 different actions covering from blowing candles to playing violin. We will use [a smaller subset of UCF-101](https://huggingface.co/datasets/sayakpaul/ucf101-subset).

# %%
from huggingface_hub import hf_hub_download
import tarfile
import pathlib

fpath = hf_hub_download(repo_id="sayakpaul/ucf101-subset", filename="UCF101_subset.tar.gz", repo_type="dataset")

with tarfile.open(fpath) as t:
    t.extractall(".")

dataset_root_path = pathlib.Path("UCF101_subset")
all_video_file_paths = list(dataset_root_path.glob("**/*.avi"))

# %% [markdown]
# We gather different splits as lists to later create the `DataLoader` for training.

# %%
train_video_file_paths = []
val_video_file_paths = []
test_video_file_paths = []

for video_file_path in all_video_file_paths:
    video_parts = video_file_path.parts
    if "train" in video_parts:
        train_video_file_paths.append(video_file_path)
    elif "val" in video_parts:
        val_video_file_paths.append(video_file_path)
    elif "test" in video_parts:
        test_video_file_paths.append(video_file_path)
    else:
        raise ValueError(f"Unknown video part: {video_parts}")

video_count_train = len(train_video_file_paths)
video_count_val = len(val_video_file_paths)
video_count_test = len(test_video_file_paths)

video_total = video_count_train + video_count_val + video_count_test
print(f"Total videos: {video_total}")
# Out:
# Total videos: 405

# %% [markdown]
# We need to keep a class label to human-readable label mapping and number of classes to later initialize our model.

# %%
class_labels = {path.parts[2] for path in all_video_file_paths}
label2id = {label: i for i, label in enumerate(class_labels)}
id2label = {i: label for label, i in label2id.items()}

# %% [markdown]
# We will create a `CustomVideoDataset` class and initialize our train/test/validation sets for DataLoader.

# %%
from torch.utils.data import Dataset, DataLoader
from torchcodec.decoders import VideoDecoder

class CustomVideoDataset(Dataset):
    def __init__(self, video_file_paths, label2id):
        self.video_file_paths = video_file_paths
        self.label2id = label2id

    def __len__(self):
        return len(self.video_file_paths)

    def __getitem__(self, idx):
        video_path = self.video_file_paths[idx]
        label = video_path.parts[2]
        decoder = VideoDecoder(video_path)
        return decoder, self.label2id[label]

train_ds = CustomVideoDataset(train_video_file_paths, label2id)
val_ds = CustomVideoDataset(val_video_file_paths, label2id)
test_ds = CustomVideoDataset(test_video_file_paths, label2id)

# %% [markdown]
# V-JEPA 2 is an embedding model. To fine-tune it, we need to load the weights with a randomly initialized task-specific head put on top of them. For this, we can use `VJEPA2ForVideoClassification` class. During the initialization, we should pass in the mapping between the class labels and human readable labels, so the classification head has the same number of classes, and directly outputs human-readable labels with the confidence scores.
#
# On a separate note, if you want to only use embeddings, you can use `AutoModel` to do so. This can be used for e.g. video-to-video retrieval or calculating similarity between videos.

# %% [markdown]
# We can now define augmentations and create the data collator. This notebook is made for tutorial purposes, so we keep the augmentations minimal. We can finally initialize the DataLoader afterwards.

# %%
from torchcodec.samplers import clips_at_random_indices
from torchvision.transforms import v2


def collate_fn(
    samples, frames_per_clip, transforms
):
    """Sample clips and apply transforms to a batch."""
    clips, labels = [], []
    for decoder, lbl in samples:
        clip = clips_at_random_indices(
            decoder,
            num_clips=1,
            num_frames_per_clip=frames_per_clip,
            num_indices_between_frames=3,
        ).data
        clips.append(clip)
        labels.append(lbl)

    videos = torch.cat(clips, dim=0)
    videos = transforms(videos)
    return videos, torch.tensor(labels)



train_transforms = v2.Compose([
        v2.RandomResizedCrop((processor.crop_size["height"], processor.crop_size["width"])),
        v2.RandomHorizontalFlip(),
    ])
eval_transforms = v2.Compose([
        v2.CenterCrop((processor.crop_size["height"], processor.crop_size["width"]))
    ])

# %%
from functools import partial

batch_size = 1
num_workers = 8

# DataLoaders
train_loader = DataLoader(
    train_ds,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=partial(collate_fn, frames_per_clip=model.config.frames_per_clip, transforms=train_transforms),
    num_workers=num_workers,
    pin_memory=True,
)
val_loader = DataLoader(
    val_ds,
    batch_size=batch_size,
    shuffle=False,
    collate_fn=partial(collate_fn, frames_per_clip=model.config.frames_per_clip, transforms=eval_transforms),
    num_workers=num_workers,
    pin_memory=True,
)
test_loader = DataLoader(
    test_ds,
    batch_size=batch_size,
    shuffle=False,
    collate_fn=partial(collate_fn, frames_per_clip=model.config.frames_per_clip, transforms=eval_transforms),
    num_workers=num_workers,
    pin_memory=True,
)

# %% [markdown]
# ## Model Training

# %% [markdown]
# Before training, we will login to HF Hub (to later push the model) and setup tensorboard.

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter("runs/vjepa2_finetune")

# %% [markdown]
# Here's a small evaluation function we use so we evaluate the model training and log the number to tensorboard.

# %%
def evaluate(
    loader: DataLoader,
    model: VJEPA2ForVideoClassification,
    processor: VJEPA2VideoProcessor,
    device: torch.device,
) -> float:
    """Compute accuracy over a dataset."""
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for vids, labels in loader:
            inputs = processor(vids, return_tensors="pt").to(device)
            labels = labels.to(device)
            logits = model(**inputs).logits
            preds = logits.argmax(-1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
    return correct / total if total > 0 else 0.0

# %% [markdown]
# Finally, write the training loop!
# - On A100 we can fit in single example, so for better performance we will use gradient accumulation to simulate larger batch sizes.
# - We will freeze the backbone completely and only train the head.
# - We will use Adam optimizer.
# - We need to initialize the model head with the new labels.

# %%
del model
model_name = "qubvel-hf/vjepa2-vitl-fpc16-256-ssv2"
processor = VJEPA2VideoProcessor.from_pretrained(model_name)
model = VJEPA2ForVideoClassification.from_pretrained(
    model_name,
    torch_dtype=torch.float32,
    label2id=label2id,
    id2label=id2label,
    ignore_mismatched_sizes=True,
).to("cuda")
# Out:
# Some weights of VJEPA2ForVideoClassification were not initialized from the model checkpoint at qubvel-hf/vjepa2-vitl-fpc16-256-ssv2 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([174]) in the checkpoint and torch.Size([10]) in the model instantiated
# - classifier.weight: found shape torch.Size([174, 1024]) in the checkpoint and torch.Size([10, 1024]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
gradient_accumulation_steps = 4

for param in model.vjepa2.parameters():
        param.requires_grad = False

# Optimizer and loss
trainable = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.Adam(trainable, lr=1e-5)

# %%
# Training loop with gradient accumulation and evaluation
num_epochs = 5
accumulation_steps = 4
for epoch in range(1, num_epochs + 1):
    model.train()
    running_loss = 0.0
    optimizer.zero_grad()
    for step, (vids, labels) in enumerate(train_loader, start=1):
        inputs = processor(vids, return_tensors="pt").to(model.device)
        labels = labels.to(model.device)
        outputs = model(**inputs, labels=labels)
        loss = outputs.loss / accumulation_steps
        loss.backward()
        running_loss += loss.item()

        if step % accumulation_steps == 0:
            optimizer.step()
            optimizer.zero_grad()
            print(f"Epoch {epoch} Step {step}: Accumulated Loss = {running_loss:.4f}")
            running_loss = 0.0

    # End of epoch evaluation
    val_acc = evaluate(val_loader, model, processor, model.device)
    print(f"Epoch {epoch} Validation Accuracy: {val_acc:.4f}")
    writer.add_scalar("Val Acc", val_acc, epoch * len(train_loader)) # Log loss



# Final test evaluation
test_acc = evaluate(test_loader, model, processor, model.device)
print(f"Final Test Accuracy: {test_acc:.4f}")
writer.add_scalar("Final Test Acc", test_acc, epoch * len(train_loader) + step) # Log loss
writer.close()
# Out:
# Epoch 1 Step 4: Accumulated Loss = 2.4374
# Epoch 1 Step 8: Accumulated Loss = 2.4301
# Epoch 1 Step 12: Accumulated Loss = 2.6364
# Epoch 1 Step 16: Accumulated Loss = 2.4991
# Epoch 1 Step 20: Accumulated Loss = 2.5215
# Epoch 1 Step 24: Accumulated Loss = 2.4089
# Epoch 1 Step 28: Accumulated Loss = 2.3870
# Epoch 1 Step 32: Accumulated Loss = 2.2417
# Epoch 1 Step 36: Accumulated Loss = 2.6394
# Epoch 1 Step 40: Accumulated Loss = 2.4861
# Epoch 1 Step 44: Accumulated Loss = 2.6568
# Epoch 1 Step 48: Accumulated Loss = 2.2627
# Epoch 1 Step 52: Accumulated Loss = 2.5263
# Epoch 1 Step 56: Accumulated Loss = 2.2626
# Epoch 1 Step 60: Accumulated Loss = 2.1493
# Epoch 1 Step 64: Accumulated Loss = 2.3545
# Epoch 1 Step 68: Accumulated Loss = 2.2872
# Epoch 1 Step 72: Accumulated Loss = 2.0267
# Epoch 1 Step 76: Accumulated Loss = 2.4484
# Epoch 1 Step 80: Accumulated Loss = 2.1420
# Epoch 1 Step 84: Accumulated Loss = 2.4607
# Epoch 1 Step 88: Accumulated Loss = 2.5552
# Epoch 1 Step 92: Accumulated Loss = 2.3860
# Epoch 1 Step 96: Accumulated Loss = 2.1629
# Epoch 1 Step 100: Accumulated Loss = 2.4949
# Epoch 1 Step 104: Accumulated Loss = 2.2526
# Epoch 1 Step 108: Accumulated Loss = 2.1343
# Epoch 1 Step 112: Accumulated Loss = 2.2793
# Epoch 1 Step 116: Accumulated Loss = 1.9160
# Epoch 1 Step 120: Accumulated Loss = 2.2710
# Epoch 1 Step 124: Accumulated Loss = 2.6402
# Epoch 1 Step 128: Accumulated Loss = 2.3268
# Epoch 1 Step 132: Accumulated Loss = 2.2637
# Epoch 1 Step 136: Accumulated Loss = 2.3056
# Epoch 1 Step 140: Accumulated Loss = 1.9433
# Epoch 1 Step 144: Accumulated Loss = 2.5684
# Epoch 1 Step 148: Accumulated Loss = 2.0994
# Epoch 1 Step 152: Accumulated Loss = 2.3325
# Epoch 1 Step 156: Accumulated Loss = 2.2036
# Epoch 1 Step 160: Accumulated Loss = 2.2418
# Epoch 1 Step 164: Accumulated Loss = 2.4737
# Epoch 1 Step 168: Accumulated Loss = 2.1102
# Epoch 1 Step 172: Accumulated Loss = 2.2295
# Epoch 1 Step 176: Accumulated Loss = 2.1759
# Epoch 1 Step 180: Accumulated Loss = 2.1245
# Epoch 1 Step 184: Accumulated Loss = 2.2936
# Epoch 1 Step 188: Accumulated Loss = 2.2201
# Epoch 1 Step 192: Accumulated Loss = 2.1238
# Epoch 1 Step 196: Accumulated Loss = 2.1434
# Epoch 1 Step 200: Accumulated Loss = 2.2267
# Epoch 1 Step 204: Accumulated Loss = 2.0451
# Epoch 1 Step 208: Accumulated Loss = 2.1340
# Epoch 1 Step 212: Accumulated Loss = 2.0615
# Epoch 1 Step 216: Accumulated Loss = 2.1408
# Epoch 1 Step 220: Accumulated Loss = 1.8669
# Epoch 1 Step 224: Accumulated Loss = 2.0821
# Epoch 1 Step 228: Accumulated Loss = 2.0060
# Epoch 1 Step 232: Accumulated Loss = 2.0880
# Epoch 1 Step 236: Accumulated Loss = 2.2563
# Epoch 1 Step 240: Accumulated Loss = 2.2102
# Epoch 1 Step 244: Accumulated Loss = 1.8373
# Epoch 1 Step 248: Accumulated Loss = 1.9634
# Epoch 1 Step 252: Accumulated Loss = 2.3135
# Epoch 1 Step 256: Accumulated Loss = 1.8222
# Epoch 1 Step 260: Accumulated Loss = 2.2721
# Epoch 1 Step 264: Accumulated Loss = 2.0542
# Epoch 1 Step 268: Accumulated Loss = 2.2561
# Epoch 1 Step 272: Accumulated Loss = 2.2086
# Epoch 1 Step 276: Accumulated Loss = 1.7952
# Epoch 1 Step 280: Accumulated Loss = 2.0611
# Epoch 1 Step 284: Accumulated Loss = 2.0211
# Epoch 1 Step 288: Accumulated Loss = 1.9916
# Epoch 1 Step 292: Accumulated Loss = 1.8564
# Epoch 1 Step 296: Accumulated Loss = 2.1187
# Epoch 1 Step 300: Accumulated Loss = 1.8814
# Epoch 1 Validation Accuracy: 0.3333
# Epoch 2 Step 4: Accumulated Loss = 1.6526
# Epoch 2 Step 8: Accumulated Loss = 1.9335
# Epoch 2 Step 12: Accumulated Loss = 2.2624
# Epoch 2 Step 16: Accumulated Loss = 2.0382
# Epoch 2 Step 20: Accumulated Loss = 1.9667
# Epoch 2 Step 24: Accumulated Loss = 1.9171
# Epoch 2 Step 28: Accumulated Loss = 2.0657
# Epoch 2 Step 32: Accumulated Loss = 1.9189
# Epoch 2 Step 36: Accumulated Loss = 2.0267
# Epoch 2 Step 40: Accumulated Loss = 2.2903
# Epoch 2 Step 44: Accumulated Loss = 2.0132
# Epoch 2 Step 48: Accumulated Loss = 2.1886
# Epoch 2 Step 52: Accumulated Loss = 1.7217
# Epoch 2 Step 56: Accumulated Loss = 1.5484
# Epoch 2 Step 60: Accumulated Loss = 1.8083
# Epoch 2 Step 64: Accumulated Loss = 1.8589
# Epoch 2 Step 68: Accumulated Loss = 1.7979
# Epoch 2 Step 72: Accumulated Loss = 1.8580
# Epoch 2 Step 76: Accumulated Loss = 2.2323
# Epoch 2 Step 80: Accumulated Loss = 1.7978
# Epoch 2 Step 84: Accumulated Loss = 1.9081
# Epoch 2 Step 88: Accumulated Loss = 1.9152
# Epoch 2 Step 92: Accumulated Loss = 1.9260
# Epoch 2 Step 96: Accumulated Loss = 1.9428
# Epoch 2 Step 100: Accumulated Loss = 1.9791
# Epoch 2 Step 104: Accumulated Loss = 1.7323
# Epoch 2 Step 108: Accumulated Loss = 1.8499
# Epoch 2 Step 112: Accumulated Loss = 1.8400
# Epoch 2 Step 116: Accumulated Loss = 1.2740
# Epoch 2 Step 120: Accumulated Loss = 1.5789
# Epoch 2 Step 124: Accumulated Loss = 1.4851
# Epoch 2 Step 128: Accumulated Loss = 1.8552
# Epoch 2 Step 132: Accumulated Loss = 1.8511
# Epoch 2 Step 136: Accumulated Loss = 1.2891
# Epoch 2 Step 140: Accumulated Loss = 1.5249
# Epoch 2 Step 144: Accumulated Loss = 1.2709
# Epoch 2 Step 148: Accumulated Loss = 1.7184
# Epoch 2 Step 152: Accumulated Loss = 1.8027
# Epoch 2 Step 156: Accumulated Loss = 1.7201
# Epoch 2 Step 160: Accumulated Loss = 1.6851
# Epoch 2 Step 164: Accumulated Loss = 1.7284
# Epoch 2 Step 168: Accumulated Loss = 1.4749
# Epoch 2 Step 172: Accumulated Loss = 1.6625
# Epoch 2 Step 176: Accumulated Loss = 1.7333
# Epoch 2 Step 180: Accumulated Loss = 1.6522
# Epoch 2 Step 184: Accumulated Loss = 1.7042
# Epoch 2 Step 188: Accumulated Loss = 1.7060
# Epoch 2 Step 192: Accumulated Loss = 1.6794
# Epoch 2 Step 196: Accumulated Loss = 1.6663
# Epoch 2 Step 200: Accumulated Loss = 1.6590
# Epoch 2 Step 204: Accumulated Loss = 1.6877
# Epoch 2 Step 208: Accumulated Loss = 1.3103
# Epoch 2 Step 212: Accumulated Loss = 1.7822
# Epoch 2 Step 216: Accumulated Loss = 1.3645
# Epoch 2 Step 220: Accumulated Loss = 1.6981
# Epoch 2 Step 224: Accumulated Loss = 1.1688
# Epoch 2 Step 228: Accumulated Loss = 1.5811
# Epoch 2 Step 232: Accumulated Loss = 1.8784
# Epoch 2 Step 236: Accumulated Loss = 1.6202
# Epoch 2 Step 240: Accumulated Loss = 1.6725
# Epoch 2 Step 244: Accumulated Loss = 1.3409
# Epoch 2 Step 248: Accumulated Loss = 1.8178
# Epoch 2 Step 252: Accumulated Loss = 1.7902
# Epoch 2 Step 256: Accumulated Loss = 1.5866
# Epoch 2 Step 260: Accumulated Loss = 1.6365
# Epoch 2 Step 264: Accumulated Loss = 1.6587
# Epoch 2 Step 268: Accumulated Loss = 1.5618
# Epoch 2 Step 272: Accumulated Loss = 1.0878
# Epoch 2 Step 276: Accumulated Loss = 1.2646
# Epoch 2 Step 280: Accumulated Loss = 1.3983
# Epoch 2 Step 284: Accumulated Loss = 1.3916
# Epoch 2 Step 288: Accumulated Loss = 2.2084
# Epoch 2 Step 292: Accumulated Loss = 1.4725
# Epoch 2 Step 296: Accumulated Loss = 1.3443
# Epoch 2 Step 300: Accumulated Loss = 1.2341
# Epoch 2 Validation Accuracy: 0.8000
# Epoch 3 Step 4: Accumulated Loss = 1.7792
# Epoch 3 Step 8: Accumulated Loss = 1.4459
# Epoch 3 Step 12: Accumulated Loss = 1.0405
# Epoch 3 Step 16: Accumulated Loss = 1.4721
# Epoch 3 Step 20: Accumulated Loss = 1.2362
# Epoch 3 Step 24: Accumulated Loss = 1.3642
# Epoch 3 Step 28: Accumulated Loss = 1.8587
# Epoch 3 Step 32: Accumulated Loss = 1.3640
# Epoch 3 Step 36: Accumulated Loss = 1.4293
# Epoch 3 Step 40: Accumulated Loss = 1.6370
# Epoch 3 Step 44: Accumulated Loss = 1.3617
# Epoch 3 Step 48: Accumulated Loss = 1.3009
# Epoch 3 Step 52: Accumulated Loss = 1.2630
# Epoch 3 Step 56: Accumulated Loss = 0.8793
# Epoch 3 Step 60: Accumulated Loss = 1.3734
# Epoch 3 Step 64: Accumulated Loss = 1.3297
# Epoch 3 Step 68: Accumulated Loss = 1.5208
# Epoch 3 Step 72: Accumulated Loss = 0.8465
# Epoch 3 Step 76: Accumulated Loss = 1.1368
# Epoch 3 Step 80: Accumulated Loss = 0.9195
# Epoch 3 Step 84: Accumulated Loss = 1.4835
# Epoch 3 Step 88: Accumulated Loss = 0.9459
# Epoch 3 Step 92: Accumulated Loss = 1.2324
# Epoch 3 Step 96: Accumulated Loss = 1.5042
# Epoch 3 Step 100: Accumulated Loss = 1.8467
# Epoch 3 Step 104: Accumulated Loss = 1.1815
# Epoch 3 Step 108: Accumulated Loss = 1.1443
# Epoch 3 Step 112: Accumulated Loss = 1.1867
# Epoch 3 Step 116: Accumulated Loss = 1.3822
# Epoch 3 Step 120: Accumulated Loss = 1.4043
# Epoch 3 Step 124: Accumulated Loss = 1.0069
# Epoch 3 Step 128: Accumulated Loss = 1.1251
# Epoch 3 Step 132: Accumulated Loss = 1.4216
# Epoch 3 Step 136: Accumulated Loss = 1.1941
# Epoch 3 Step 140: Accumulated Loss = 1.3986
# Epoch 3 Step 144: Accumulated Loss = 0.9652
# Epoch 3 Step 148: Accumulated Loss = 0.9389
# Epoch 3 Step 152: Accumulated Loss = 1.0566
# Epoch 3 Step 156: Accumulated Loss = 1.3330
# Epoch 3 Step 160: Accumulated Loss = 1.0414
# Epoch 3 Step 164: Accumulated Loss = 1.3748
# Epoch 3 Step 168: Accumulated Loss = 1.6332
# Epoch 3 Step 172: Accumulated Loss = 1.4007
# Epoch 3 Step 176: Accumulated Loss = 0.8959
# Epoch 3 Step 180: Accumulated Loss = 1.0355
# Epoch 3 Step 184: Accumulated Loss = 0.9384
# Epoch 3 Step 188: Accumulated Loss = 1.1361
# Epoch 3 Step 192: Accumulated Loss = 0.8555
# Epoch 3 Step 196: Accumulated Loss = 0.8405
# Epoch 3 Step 200: Accumulated Loss = 1.0736
# Epoch 3 Step 204: Accumulated Loss = 1.2196
# Epoch 3 Step 208: Accumulated Loss = 1.2947
# Epoch 3 Step 212: Accumulated Loss = 1.0975
# Epoch 3 Step 216: Accumulated Loss = 0.7192
# Epoch 3 Step 220: Accumulated Loss = 1.1317
# Epoch 3 Step 224: Accumulated Loss = 1.4569
# Epoch 3 Step 228: Accumulated Loss = 1.5830
# Epoch 3 Step 232: Accumulated Loss = 0.4778
# Epoch 3 Step 236: Accumulated Loss = 0.9873
# Epoch 3 Step 240: Accumulated Loss = 1.1108
# Epoch 3 Step 244: Accumulated Loss = 1.2614
# Epoch 3 Step 248: Accumulated Loss = 1.2893
# Epoch 3 Step 252: Accumulated Loss = 0.9929
# Epoch 3 Step 256: Accumulated Loss = 1.4404
# Epoch 3 Step 260: Accumulated Loss = 0.8255
# Epoch 3 Step 264: Accumulated Loss = 1.2598
# Epoch 3 Step 268: Accumulated Loss = 0.7041
# Epoch 3 Step 272: Accumulated Loss = 1.0673
# Epoch 3 Step 276: Accumulated Loss = 0.6876
# Epoch 3 Step 280: Accumulated Loss = 0.8663
# Epoch 3 Step 284: Accumulated Loss = 0.6740
# Epoch 3 Step 288: Accumulated Loss = 0.8708
# Epoch 3 Step 292: Accumulated Loss = 1.1806
# Epoch 3 Step 296: Accumulated Loss = 0.6306
# Epoch 3 Step 300: Accumulated Loss = 0.5125
# Epoch 3 Validation Accuracy: 0.9333
# Epoch 4 Step 4: Accumulated Loss = 1.2487
# Epoch 4 Step 8: Accumulated Loss = 0.9501
# Epoch 4 Step 12: Accumulated Loss = 1.2593
# Epoch 4 Step 16: Accumulated Loss = 0.7914
# Epoch 4 Step 20: Accumulated Loss = 1.1403
# Epoch 4 Step 24: Accumulated Loss = 0.5162
# Epoch 4 Step 28: Accumulated Loss = 1.2825
# Epoch 4 Step 32: Accumulated Loss = 0.8180
# Epoch 4 Step 36: Accumulated Loss = 0.9460
# Epoch 4 Step 40: Accumulated Loss = 1.1084
# Epoch 4 Step 44: Accumulated Loss = 0.5445
# Epoch 4 Step 48: Accumulated Loss = 0.7064
# Epoch 4 Step 52: Accumulated Loss = 1.1141
# Epoch 4 Step 56: Accumulated Loss = 0.8156
# Epoch 4 Step 60: Accumulated Loss = 1.2378
# Epoch 4 Step 64: Accumulated Loss = 1.1159
# Epoch 4 Step 68: Accumulated Loss = 0.6981
# Epoch 4 Step 72: Accumulated Loss = 0.8476
# Epoch 4 Step 76: Accumulated Loss = 1.2047
# Epoch 4 Step 80: Accumulated Loss = 0.4300
# Epoch 4 Step 84: Accumulated Loss = 1.0843
# Epoch 4 Step 88: Accumulated Loss = 1.2620
# Epoch 4 Step 92: Accumulated Loss = 0.8930
# Epoch 4 Step 96: Accumulated Loss = 1.1604
# Epoch 4 Step 100: Accumulated Loss = 0.7082
# Epoch 4 Step 104: Accumulated Loss = 1.0360
# Epoch 4 Step 108: Accumulated Loss = 1.2594
# Epoch 4 Step 112: Accumulated Loss = 0.5446
# Epoch 4 Step 116: Accumulated Loss = 0.8314
# Epoch 4 Step 120: Accumulated Loss = 0.5678
# Epoch 4 Step 124: Accumulated Loss = 0.3157
# Epoch 4 Step 128: Accumulated Loss = 1.0529
# Epoch 4 Step 132: Accumulated Loss = 0.3604
# Epoch 4 Step 136: Accumulated Loss = 0.8248
# Epoch 4 Step 140: Accumulated Loss = 1.0236
# Epoch 4 Step 144: Accumulated Loss = 1.4206
# Epoch 4 Step 148: Accumulated Loss = 1.2134
# Epoch 4 Step 152: Accumulated Loss = 0.7005
# Epoch 4 Step 156: Accumulated Loss = 1.0403
# Epoch 4 Step 160: Accumulated Loss = 1.0285
# Epoch 4 Step 164: Accumulated Loss = 0.7162
# Epoch 4 Step 168: Accumulated Loss = 0.4477
# Epoch 4 Step 172: Accumulated Loss = 0.6524
# Epoch 4 Step 176: Accumulated Loss = 0.7357
# Epoch 4 Step 180: Accumulated Loss = 1.0750
# Epoch 4 Step 184: Accumulated Loss = 0.7942
# Epoch 4 Step 188: Accumulated Loss = 0.9292
# Epoch 4 Step 192: Accumulated Loss = 0.6608
# Epoch 4 Step 196: Accumulated Loss = 1.0487
# Epoch 4 Step 200: Accumulated Loss = 0.4057
# Epoch 4 Step 204: Accumulated Loss = 0.9824
# Epoch 4 Step 208: Accumulated Loss = 0.3539
# Epoch 4 Step 212: Accumulated Loss = 0.5370
# Epoch 4 Step 216: Accumulated Loss = 0.5966
# Epoch 4 Step 220: Accumulated Loss = 0.6836
# Epoch 4 Step 224: Accumulated Loss = 0.8325
# Epoch 4 Step 228: Accumulated Loss = 0.4702
# Epoch 4 Step 232: Accumulated Loss = 1.3814
# Epoch 4 Step 236: Accumulated Loss = 1.0648
# Epoch 4 Step 240: Accumulated Loss = 0.7933
# Epoch 4 Step 244: Accumulated Loss = 0.8002
# Epoch 4 Step 248: Accumulated Loss = 0.8704
# Epoch 4 Step 252: Accumulated Loss = 0.6652
# Epoch 4 Step 256: Accumulated Loss = 0.8532
# Epoch 4 Step 260: Accumulated Loss = 0.5731
# Epoch 4 Step 264: Accumulated Loss = 0.4963
# Epoch 4 Step 268: Accumulated Loss = 0.3430
# Epoch 4 Step 272: Accumulated Loss = 0.9138
# Epoch 4 Step 276: Accumulated Loss = 0.3177
# Epoch 4 Step 280: Accumulated Loss = 0.8100
# Epoch 4 Step 284: Accumulated Loss = 0.6994
# Epoch 4 Step 288: Accumulated Loss = 0.7007
# Epoch 4 Step 292: Accumulated Loss = 0.9177
# Epoch 4 Step 296: Accumulated Loss = 0.4323
# Epoch 4 Step 300: Accumulated Loss = 0.9394
# Epoch 4 Validation Accuracy: 0.9333
# Epoch 5 Step 4: Accumulated Loss = 0.3765
# Epoch 5 Step 8: Accumulated Loss = 0.2645
# Epoch 5 Step 12: Accumulated Loss = 0.3801
# Epoch 5 Step 16: Accumulated Loss = 1.0992
# Epoch 5 Step 20: Accumulated Loss = 1.4299
# Epoch 5 Step 24: Accumulated Loss = 0.4831
# Epoch 5 Step 28: Accumulated Loss = 1.3632
# Epoch 5 Step 32: Accumulated Loss = 0.7189
# Epoch 5 Step 36: Accumulated Loss = 1.1219
# Epoch 5 Step 40: Accumulated Loss = 0.3805
# Epoch 5 Step 44: Accumulated Loss = 0.7221
# Epoch 5 Step 48: Accumulated Loss = 0.7443
# Epoch 5 Step 52: Accumulated Loss = 0.5497
# Epoch 5 Step 56: Accumulated Loss = 0.4276
# Epoch 5 Step 60: Accumulated Loss = 0.9333
# Epoch 5 Step 64: Accumulated Loss = 0.6447
# Epoch 5 Step 68: Accumulated Loss = 0.5830
# Epoch 5 Step 72: Accumulated Loss = 0.2696
# Epoch 5 Step 76: Accumulated Loss = 0.5420
# Epoch 5 Step 80: Accumulated Loss = 0.6634
# Epoch 5 Step 84: Accumulated Loss = 0.7204
# Epoch 5 Step 88: Accumulated Loss = 0.5072
# Epoch 5 Step 92: Accumulated Loss = 0.8478
# Epoch 5 Step 96: Accumulated Loss = 0.3052
# Epoch 5 Step 100: Accumulated Loss = 0.4955
# Epoch 5 Step 104: Accumulated Loss = 0.6382
# Epoch 5 Step 108: Accumulated Loss = 0.5622
# Epoch 5 Step 112: Accumulated Loss = 0.4042
# Epoch 5 Step 116: Accumulated Loss = 0.8073
# Epoch 5 Step 120: Accumulated Loss = 0.4514
# Epoch 5 Step 124: Accumulated Loss = 0.6391
# Epoch 5 Step 128: Accumulated Loss = 0.6978
# Epoch 5 Step 132: Accumulated Loss = 0.4863
# Epoch 5 Step 136: Accumulated Loss = 0.4859
# Epoch 5 Step 140: Accumulated Loss = 0.9763
# Epoch 5 Step 144: Accumulated Loss = 0.2354
# Epoch 5 Step 148: Accumulated Loss = 0.4438
# Epoch 5 Step 152: Accumulated Loss = 0.2378
# Epoch 5 Step 156: Accumulated Loss = 0.8751
# Epoch 5 Step 160: Accumulated Loss = 0.4617
# Epoch 5 Step 164: Accumulated Loss = 0.4982
# Epoch 5 Step 168: Accumulated Loss = 0.3260
# Epoch 5 Step 172: Accumulated Loss = 0.7857
# Epoch 5 Step 176: Accumulated Loss = 0.7675
# Epoch 5 Step 180: Accumulated Loss = 1.1360
# Epoch 5 Step 184: Accumulated Loss = 0.5772
# Epoch 5 Step 188: Accumulated Loss = 1.1619
# Epoch 5 Step 192: Accumulated Loss = 0.6365
# Epoch 5 Step 196: Accumulated Loss = 0.4687
# Epoch 5 Step 200: Accumulated Loss = 1.8458
# Epoch 5 Step 204: Accumulated Loss = 0.7707
# Epoch 5 Step 208: Accumulated Loss = 0.5120
# Epoch 5 Step 212: Accumulated Loss = 0.2012
# Epoch 5 Step 216: Accumulated Loss = 0.3606
# Epoch 5 Step 220: Accumulated Loss = 0.1237
# Epoch 5 Step 224: Accumulated Loss = 0.2551
# Epoch 5 Step 228: Accumulated Loss = 0.3137
# Epoch 5 Step 232: Accumulated Loss = 0.3216
# Epoch 5 Step 236: Accumulated Loss = 0.1662
# Epoch 5 Step 240: Accumulated Loss = 0.3516
# Epoch 5 Step 244: Accumulated Loss = 0.7180
# Epoch 5 Step 248: Accumulated Loss = 0.6370
# Epoch 5 Step 252: Accumulated Loss = 0.6594
# Epoch 5 Step 256: Accumulated Loss = 0.9949
# Epoch 5 Step 260: Accumulated Loss = 0.8004
# Epoch 5 Step 264: Accumulated Loss = 0.4994
# Epoch 5 Step 268: Accumulated Loss = 0.5542
# Epoch 5 Step 272: Accumulated Loss = 0.5583
# Epoch 5 Step 276: Accumulated Loss = 0.2767
# Epoch 5 Step 280: Accumulated Loss = 0.7792
# Epoch 5 Step 284: Accumulated Loss = 0.7194
# Epoch 5 Step 288: Accumulated Loss = 0.4226
# Epoch 5 Step 292: Accumulated Loss = 1.0016
# Epoch 5 Step 296: Accumulated Loss = 0.1389
# Epoch 5 Step 300: Accumulated Loss = 0.6077
# Epoch 5 Validation Accuracy: 1.0000
# Final Test Accuracy: 0.9867

# %% [markdown]
# Let's push the model and the tensorboard logs to Hub.

# %%
model.push_to_hub("merve/vjepa2-vitl-fpc16-256-ssv2-ucf101")
processor.push_to_hub("merve/vjepa2-vitl-fpc16-256-ssv2-ucf101")
# Out:
# model.safetensors:   0%|          | 0.00/1.50G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/merve/vjepa2-vitl-fpc16-256-ssv2-ucf101/commit/4da9a6ab7afa6440b18257b361b635c5cf1fa3c5', commit_message='Upload processor', commit_description='', oid='4da9a6ab7afa6440b18257b361b635c5cf1fa3c5', pr_url=None, repo_url=RepoUrl('https://huggingface.co/merve/vjepa2-vitl-fpc16-256-ssv2-ucf101', endpoint='https://huggingface.co', repo_type='model', repo_id='merve/vjepa2-vitl-fpc16-256-ssv2-ucf101'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import upload_folder
upload_folder(
    repo_id="merve/vjepa2-vitl-fpc16-256-ssv2-ucf101",
    folder_path="runs",
    path_in_repo="runs")
# Out:
# events.out.tfevents.1749828509.38da49c797ee.13694.0:   0%|          | 0.00/371 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/merve/vjepa2-vitl-fpc16-256-ssv2-ucf101/commit/4c0648e3194239a9bebe1dfffff04486d130e2bb', commit_message='Upload folder using huggingface_hub', commit_description='', oid='4c0648e3194239a9bebe1dfffff04486d130e2bb', pr_url=None, repo_url=RepoUrl('https://huggingface.co/merve/vjepa2-vitl-fpc16-256-ssv2-ucf101', endpoint='https://huggingface.co', repo_type='model', repo_id='merve/vjepa2-vitl-fpc16-256-ssv2-ucf101'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# You can view the logs [here](https://huggingface.co/merve/vjepa2-vitl-fpc16-256-ssv2-ucf101/tensorboard).
#
# Let's put model to test with an in-the-wild video of a concert scene, although we don't exactly have this label, we have "Band Marching" which is the closest one.

# %%
# Utility to plot the frames
# (taken from: https://docs.pytorch.org/torchcodec/stable/generated_examples/basic_example.html#sphx-glr-generated-examples-basic-example-py)
def plot(frames, title, fname):
    try:
        from torchvision.utils import make_grid
        from torchvision.transforms.v2.functional import to_pil_image
        import matplotlib.pyplot as plt
    except ImportError:
        print("Cannot plot, please run `pip install torchvision matplotlib`")
        return

    plt.rcParams["savefig.bbox"] = 'tight'
    _, ax = plt.subplots()
    ax.imshow(to_pil_image(make_grid(frames)))
    ax.set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])
    if title is not None:
        ax.set_title(title)
    plt.tight_layout()
    plt.savefig(fname)
    plt.close()

# %%
from PIL import Image
video_url = "https://huggingface.co/datasets/merve/vlm_test_images/resolve/main/IMG_3830.mp4"
vr = VideoDecoder(video_url)
frame_idx = np.arange(0, 32)
video_frames = vr.get_frames_at(indices=frame_idx).data

video = clips_at_random_indices(
    vr,
    num_clips=1,
    num_frames_per_clip=model.config.frames_per_clip,
    num_indices_between_frames=4,
).data

plot(video[0], title="Concert Scene", fname="test.png")
display(Image.open("test.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=630x313>

# %% [markdown]
# Closest label is BandMarching so we get this.

# %%
inputs = processor(video_frames, return_tensors="pt").to(model.device)

with torch.no_grad():
    logits = model(**inputs).logits

predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", id2label[predicted_class_idx])
# Out:
# Predicted class: BandMarching

# %% [markdown]
# We're looking forward to see what you'll build with V-JEPA 2!
